# %% [markdown]
# # XML Generator for CrossRef
#
# This notebook generates the XML file for CrossRef using the output from the DL Batch Revise Export.
#
# For this one we're following the example metadata for Conference Proceedings with Papers: [https://gitlab.com/crossref/schema/-/blob/master/best-practice-examples/conf_series5.3.0.xml](https://gitlab.com/crossref/schema/-/blob/master/best-practice-examples/conf_series5.3.0.xml)

# %%
import pandas as pd
from lxml import etree
from datetime import datetime

# %% [markdown]
# ## (ASIDE) Helper Functions

# %%
# Create a function to check the state of XML at any point:

def view_xml_result():
    # Pretty-print the XML
    xml_string = etree.tostring(doi_batch, pretty_print=True, xml_declaration=True, encoding="utf-8").decode("utf-8")

    # Print the formatted XML
    print(xml_string)

# %% [markdown]
# # VARIABLES
#
# Here are the variables we can control for generating the XML

# %%
# MODIFY THESE VARIABLES

DATA_FILE_NAME = "drs2018"

BATCH_ID_NAME = "drs2018"
CONFERENCE = {"name": "DRS2018: Design as a catalyst for change",
              "acronym": "DRS2018"}

START_DATE = "2018-06-25"
END_DATE = "2018-06-28"


ISSN = "23983132"

SERIES_TITLE = "Proceedings of DRS"

# ISBN = "9781912294626"
ISBN = ""

CONFERENCE_VOLUME_DOI = "10.21606/drs.2018.v1"
CONFERENCE_VOLUME_URL = "https://dl.designresearchsociety.org/conference-volumes/36/"

# You set this by checking the CSV file to see what's the most number of authors a paper has.
MAX_AUTHORS = 7

# %%
# DO NOT MODIFY THESE VARIABLES
today = datetime.now()

SUBMISSION_TIMESTAMP = today.strftime("%Y%m%d%H%M%S") + "0000"

# %% [markdown]
# # Generate root element

# %%
# Define namespaces without 'xmlns:' in the keys
namespaces = {
    "xsi": "http://www.w3.org/2001/XMLSchema-instance",
    None: "http://www.crossref.org/schema/5.3.0",  # Default namespace
    "jats": "http://www.ncbi.nlm.nih.gov/JATS1",
    "fr": "http://www.crossref.org/fundref.xsd",
    "mml": "http://www.w3.org/1998/Math/MathML",
}

# Create the root element with namespaces
doi_batch = etree.Element("doi_batch", nsmap=namespaces)

doi_batch.set("version", "5.3.0")

doi_batch.set(
    "{http://www.w3.org/2001/XMLSchema-instance}schemaLocation",
    "http://www.crossref.org/schema/5.3.0 https://www.crossref.org/schemas/crossref5.3.0.xsd"
)

# Add head and body
head = etree.SubElement(doi_batch, "head")
body = etree.SubElement(doi_batch, "body")

# %% [markdown]
# # 01 - Populate head

# %%
today_short = today.strftime("%y%m%d")

doi_batch_id = etree.SubElement(head, "doi_batch_id").text = BATCH_ID_NAME + "__" + today_short
timestamp = etree.SubElement(head, "timestamp").text = SUBMISSION_TIMESTAMP

depositor = etree.SubElement(head, "depositor")
depositor_name = etree.SubElement(depositor, "depositor_name").text = "desres:desres"
email_address = etree.SubElement(depositor, "email_address").text = ("dl@designresearchsociety.org")

registrant = etree.SubElement(head, "registrant").text = "Digital Library"

view_xml_result()
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <doi_batch xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.crossref.org/schema/5.3.0" xmlns:jats="http://www.ncbi.nlm.nih.gov/JATS1" xmlns:fr="http://www.crossref.org/fundref.xsd" xmlns:mml="http://www.w3.org/1998/Math/MathML" version="5.3.0" xsi:schemaLocation="http://www.crossref.org/schema/5.3.0 https://www.crossref.org/schemas/crossref5.3.0.xsd">
#   <head>
#     <doi_batch_id>drs2018__250418</doi_batch_id>
#     <timestamp>202504182210270000</timestamp>
#     <depositor>
#       <depositor_name>desres:desres</depositor_name>
#       <email_address>dl@designresearchsociety.org</email_address>
#     </depositor>
#     <registrant>Digital Library</registrant>
#   </head>
#   <body/>
# </doi_batch>

# %% [markdown]
# # 02 - Load Data
#
# We want to load the data. For now we only need a copy of the first row to get conference dates.

# %%
df = pd.read_csv(DATA_FILE_NAME+".csv", sep=",")

# make a copy of the first row and keep the columns we want
first_row= df.iloc[0].copy()
first_row = first_row.fillna('').astype(str)
first_row_metadata = first_row[["conference_dates"]]

# we need to process first_row_metadata to get the start and end dates cleanly for the xml
def extract_date_parts(datetime_str):
    # date_part = datetime_str.split(" ")[0]
    # year, month, day = date_part.split("-")
    year, month, day = datetime_str.split("-")  # Split into components
    return [day, month, year]

start_date_parts = extract_date_parts(START_DATE)
end_date_parts = extract_date_parts(END_DATE)

# %% [markdown]
# # 03 - Create body structure

# %%
# conference is the container for everything in body
conference = etree.SubElement(body, "conference")


def make_body_structure():
    # event_metadata contains info about the particular proceeding
    event_metadata = etree.SubElement(conference, "event_metadata")
    conference_name = etree.SubElement(event_metadata, "conference_name").text = CONFERENCE["name"]
    conference_acronym = etree.SubElement(event_metadata, "conference_acronym").text = CONFERENCE["acronym"]

    # conference_date is something we set.
    conference_date = etree.SubElement(event_metadata, "conference_date")
    conference_date.text = first_row_metadata["conference_dates"]
    attributes = ["day", "month", "year"]

    for attr, start_value, end_value in zip(attributes, start_date_parts, end_date_parts):
        conference_date.set(f"start_{attr}", start_value)
        conference_date.set(f"end_{attr}", end_value)

    # proceedings_series_metadata keeps info about the series.
    proceedings_series_metadata = etree.SubElement(conference, "proceedings_series_metadata")

    # series_metadata is part of proceedings_series_metadata
    series_metadata = etree.SubElement(proceedings_series_metadata, "series_metadata")
    titles_series = etree.SubElement(series_metadata, "titles")
    title_series = etree.SubElement(titles_series, "title")
    title_series.text = SERIES_TITLE
    issn = etree.SubElement(series_metadata, "issn").text = ISSN

    # proceedings_title
    proceedings_title = etree.SubElement(proceedings_series_metadata, "proceedings_title").text = CONFERENCE["name"]

    publisher = etree.SubElement(proceedings_series_metadata, "publisher")
    publisher_name = etree.SubElement(publisher, "publisher_name").text = "Design Research Society"


    # publication_date > month, day, year
    publication_date = etree.SubElement(proceedings_series_metadata, "publication_date")
    publication_month = etree.SubElement(publication_date, "month").text = start_date_parts[1]
    publication_day = etree.SubElement(publication_date, "day").text = start_date_parts[0]
    publication_year = etree.SubElement(publication_date, "year").text = start_date_parts[2]

    if len(ISBN) > 0:
        isbn = etree.SubElement(proceedings_series_metadata, "isbn").text = ISBN
    else:
        isbn = etree.SubElement(proceedings_series_metadata, "noisbn")
        isbn.set("reason", "simple_series")

    doi_data = etree.SubElement(proceedings_series_metadata, "doi_data")
    doi = etree.SubElement(doi_data, "doi").text = CONFERENCE_VOLUME_DOI
    resource = etree.SubElement(doi_data, "resource").text = CONFERENCE_VOLUME_URL

# %%
body.clear()
make_body_structure()
view_xml_result()
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <doi_batch xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.crossref.org/schema/5.3.0" xmlns:jats="http://www.ncbi.nlm.nih.gov/JATS1" xmlns:fr="http://www.crossref.org/fundref.xsd" xmlns:mml="http://www.w3.org/1998/Math/MathML" version="5.3.0" xsi:schemaLocation="http://www.crossref.org/schema/5.3.0 https://www.crossref.org/schemas/crossref5.3.0.xsd">
#   <head>
#     <doi_batch_id>drs2018__250418</doi_batch_id>
#     <timestamp>202504182210270000</timestamp>
#     <depositor>
#       <depositor_name>desres:desres</depositor_name>
#       <email_address>dl@designresearchsociety.org</email_address>
#     </depositor>
#     <registrant>Digital Library</registrant>
#   </head>
#   <body/>
# </doi_batch>

# %% [markdown]
# # 04 - Select Columns for papers
#
# The `df` we loaded before has too many columns for dealing with our papers. Let's select only the ones we need.

# %%
df = pd.read_csv(DATA_FILE_NAME+".csv", sep=",")

content_cols = ["title", "calc_url", "doi"]

for x in range(1, MAX_AUTHORS+1):
    for y in ["fname", "lname", "institution"]:
        content_cols.append(f"author{x}_{y}")

df_core = df[content_cols]
df_core = df_core.fillna('').astype(str)
# df_core.head(10)
df_core.columns
# Out:
# Index(['title', 'calc_url', 'doi', 'author1_fname', 'author1_lname',
#        'author1_institution', 'author2_fname', 'author2_lname',
#        'author2_institution', 'author3_fname', 'author3_lname',
#        'author3_institution', 'author4_fname', 'author4_lname',
#        'author4_institution', 'author5_fname', 'author5_lname',
#        'author5_institution', 'author6_fname', 'author6_lname',
#        'author6_institution', 'author7_fname', 'author7_lname',
#        'author7_institution'],
#       dtype='object')

# %% [markdown]
# # 05 - Create conference paper

# %%
DETAILED_INFO = False

def generate_papers():
    for index, row in df_core.iterrows():
        print("-----\n")
        print(f"Working on row {index}: {row['title']}")

        if DETAILED_INFO:
            print("Row details:")
            for col in row.index:
                print(f"  {col}: {row[col]}")

        # Create the right XML
        conference_paper = etree.SubElement(conference, "conference_paper")
        conference_paper.set("language", "en")
        conference_paper.set("publication_type", "full_text")

        #contributors
        contributors = etree.SubElement(conference_paper, "contributors")
        #titles
        titles = etree.SubElement(conference_paper, "titles")
        title = etree.SubElement(titles, "title")
        title.text = row["title"]

        #publication_date
        publication_date = etree.SubElement(conference_paper, "publication_date")
        publication_date.set("media_type", "online")
        publication_month = etree.SubElement(publication_date, "month").text = start_date_parts[1]
        publication_day = etree.SubElement(publication_date, "day").text = start_date_parts[0]
        publication_year = etree.SubElement(publication_date, "year").text = start_date_parts[2]

        #doi_data
        doi_data = etree.SubElement(conference_paper, "doi_data")
        doi = etree.SubElement(doi_data, "doi").text = row["doi"]
        resource = etree.SubElement(doi_data, "resource").text = row["calc_url"]


        # Populate contributors
        # add author1
        author1 = etree.SubElement(contributors, "person_name")
        author1.set("sequence", "first")
        author1.set("contributor_role", "author")
        author1_given_name = etree.SubElement(author1, "given_name").text = row["author1_fname"].strip()
        author1_surname = etree.SubElement(author1, "surname").text = row["author1_lname"].strip()
        author1_affiliation = etree.SubElement(author1, "affiliations")
        author1_institution = etree.SubElement(author1_affiliation, "institution")
        author1_institution_name = etree.SubElement(author1_institution, "institution_name").text = row["author1_institution"].strip()

        print(row["doi"], row["author1_fname"])

        # add additional authors
        for x in range(2, MAX_AUTHORS+1):
            fname = row[f"author{x}_fname"].strip()

            if not fname:  # Check if fname is an empty string
                break

            author = etree.SubElement(contributors, "person_name")
            author.set("sequence", "additional")
            author.set("contributor_role", "author")
            given_name = etree.SubElement(author, "given_name").text = fname
            surname = etree.SubElement(author, "surname").text = row[f"author{x}_lname"].strip()
            affiliation = etree.SubElement(author, "affiliations")
            institution = etree.SubElement(affiliation, "institution")
            institution_name = etree.SubElement(institution, "institution_name").text = row[f"author{x}_institution"].strip()


    print("====\n ALL DONE")

# %%
body.clear()
# conference is the container for everything in body
conference = etree.SubElement(body, "conference")
make_body_structure()
generate_papers()
# view_xml_result()
# Out:
# -----
#
# Working on row 0: Introducing Design-Driven Innovation into Brazilian MSMEs: barriers and next challenges of design support
# 10.21606/drs.2018.442 Mariana
# -----
#
# Working on row 1: Combining Practices in Craft and Design
# 10.21606/drs.2018.537 Micheal
# -----
#
# Working on row 2: Co-creating Happy Moments: A Case Study of Designing for People with Mental Health Challenges
# 10.21606/drs.2018.214 Hong
# -----
#
# Working on row 3: The Design and Social Enterprise Ecosystem: How can design be applied to a developing social enterprise ecosystem?
# 10.21606/drs.2018.283 Kwon
# -----
#
# Working on row 4: Editorial: How Organisations Employ Design as Vehicle for Change
# 10.21606/drs.2018.78 Chris
# -----
#
# Working on row 5: Editorial: Designing Social Innovation in Cultural Diversity and with Sensitivity
# 10.21606/drs.2018.007 Joon
# -----
#
# Working on row 6: Social Hierarchy in Design and Social Innovation: perspectives from Thailand
# 10.21606/drs.2018.420 Cyril
# -----
#
# Working on row 7: Healthy Self-Management Communities by Design
# 10.21606/drs.2018.545 Liren
# -----
#
# Working on row 8: Card-based Tools for Creative and Systematic Design
# 10.21606/drs.2018.284 Robin
# -----
#
# Working on row 9: Evaluating Inclusivity using Quantitative Personas
# 10.21606/drs.2018.400 Joy
# -----
#
# Working on row 10: Shifting Towards a User-Centred Approach for Resource-Efficient Building: lessons from an educational study
# 10.21606/drs.2018.385 Ann
# -----
#
# Working on row 11: Conversation: Smuggling ideologies? Inquiring into the underlying ideas embedded in design for public governance and policy-making
# 10.21606/drs.2018.783 Maria
# -----
#
# Working on row 12: Designing for Lifelong Sports Experience
# 10.21606/drs.2018.413 Armağan
# -----
#
# Working on row 13: Design Probes for People with Dementia
# 10.21606/drs.2018.492 Julia Anne
# -----
#
# Working on row 14: Editorial: Drawing as a Powerful Catalyst for Design Driven Research and Creation
# 10.21606/drs.2018.011 Thierry
# -----
#
# Working on row 15: Regimes of Digital Quantification: making data-driven decisions?
# 10.21606/drs.2018.570 Martin
# -----
#
# Working on row 16: Mentian: Developing Design Fiction for Dementia Policy
# 10.21606/drs.2018.608 Andy
# -----
#
# Working on row 17: Editorial: Ethics, Values, and Designer Responsibility
# 10.21606/drs.2018.003 Colin M.
# -----
#
# Working on row 18: Co-designing Wellbeing: the commonality of needs between co-designers and mental health service users
# 10.21606/drs.2018.405 Laura
# -----
#
# Working on row 19: Have I Got a Proposition for You: Developing the capability for compelling arguments through rhetorical practice inthe design studio
# 10.21606/drs.2018.505 Veronika
# -----
#
# Working on row 20: Designerly Activity Theory: toward a new ontology for design research
# 10.21606/drs.2018.197 Mithra
# -----
#
# Working on row 21: The Interconnected Process of Design and Science: a method for mapping concepts and knowledge
# 10.21606/drs.2018.637 Carol
# -----
#
# Working on row 22: Aestheticising Change: simulations of progress
# 10.21606/drs.2018.291 Jocelyn
# -----
#
# Working on row 23: How Emerging Technologies Influence Designing – The Case of Conversational Agents and Interaction Design
# 10.21606/drs.2018.330 Connor
# -----
#
# Working on row 24: Three Arguments About the Current State of Scientific Design Process Theories
# 10.21606/drs.2018.555 Jordan
# -----
#
# Working on row 25: Transition Design: teaching and learning
# 10.21606/drs.2018.282 Stacie
# -----
#
# Working on row 26: Soma-Wearable Design: Integrating Somaesthetic Practice and Fashion Design for Somatic Wellbeing
# 10.21606/drs.2018.646 Heekyoung
# -----
#
# Working on row 27: From Wicked Problem to Design Problem: developing actionable briefs and solution opportunities through a collaborative, multidisciplinary design-led approach
# 10.21606/drs.2018.586 Mark
# -----
#
# Working on row 28: Conversation: Woman-Centred Design
# 10.21606/drs.2018.795 Teresa
# -----
#
# Working on row 29: Contemporary Automotive Infotainment Solutions to Empower Front-Seat Passengers
# 10.21606/drs.2018.444 Guzin
# -----
#
# Working on row 30: Overcoming Design Fixation in Idea Generation
# 10.21606/drs.2018.349 Keelin
# -----
#
# Working on row 31: Responding to Diversity Including Disability
# 10.21606/drs.2018.524 René
# -----
#
# Working on row 32: Using Design Competencies to Define Curricula and Support Learners
# 10.21606/drs.2018.578 John
# -----
#
# Working on row 33: Smart Citizenship: designing the interaction between citizens and smart cities
# 10.21606/drs.2018.480 Priscilla
# -----
#
# Working on row 34: Ambiguity and Open-Endedness in Behavioural Design
# 10.21606/drs.2018.452 Boudewijn
# -----
#
# Working on row 35: Do Professionals with Different Backgrounds Use Distinct Thinking Styles When Designing a Product?
# 10.21606/drs.2018.356 Roberta Rech
# -----
#
# Working on row 36: Conversation: Transforming Design: Indigeneity and Mestizaje in Latin America
# 10.21606/drs.2018.746 Gabriela
# -----
#
# Working on row 37: Why We Need Engineers to Make Art
# 10.21606/drs.2018.304 Giovanni
# -----
#
# Working on row 38: Research-Through-Design: Exploring a design-based research paradigm through its ontology, epistemology, and methodolog
# 10.21606/drs.2018.263 C. Grey
# -----
#
# Working on row 39: Data Streams, Data Seams: Toward a seamful representationof data interoperability
# 10.21606/drs.2018.359 Sarah
# -----
#
# Working on row 40: Re-framing Product Circularity from a User Perspective
# 10.21606/drs.2018.652 Anneli
# -----
#
# Working on row 41: Heuristics for selecting and using behavioural design methods
# 10.21606/drs.2018.607 Nynke
# -----
#
# Working on row 42: Innovation Development in Norwegian Public Schools. The relationship between innovation, creativity and imagination
# 10.21606/drs.2018.614 Jorid
# -----
#
# Working on row 43: Platform Ethics in Technology: What Happens to the User?
# 10.21606/drs.2018.321 Anuradha
# -----
#
# Working on row 44: ICS Materials. Towards a Re-Interpretation of Material Qualities Through Interactive, Connected, and Smart Materials.
# 10.21606/drs.2018.521 Stefano
# -----
#
# Working on row 45: Critical Placemaking: towards a more critical engagement for participatory design in the urban environment
# 10.21606/drs.2018.675 Tania
# -----
#
# Working on row 46: Redesigning Migrant Children’s Education Through Service Design in Shanghai
# 10.21606/drs.2018.509 Gao
# -----
#
# Working on row 47: Designing Machines with Autonomy: from independence to interdependence to solidarity
# 10.21606/drs.2018.394 Yuxi
# -----
#
# Working on row 48: Design Capability in a Software SME: report from an embedded design innovation catalyst
# 10.21606/drs.2018.415 Sjoerd J.B.M.
# -----
#
# Working on row 49: Designing with Meaningful Data: Deep personalisation in the air travel context
# 10.21606/drs.2018.287 Mengqi
# -----
#
# Working on row 50: Using Dynamic Capabilities in an Actionable Tool as a Vehicle to Initiate Design-Driven Innovation
# 10.21606/drs.2018.287 Barenda
# -----
#
# Working on row 51: Heart Sense: experiments in design as a catalyst for feminist reflections on embodiment
# 10.21606/drs.2018.409 Nassim
# -----
#
# Working on row 52: Toward a More Granular Management of the Calibration Process for Hearing Devices: the role of design-based knowledge translation
# 10.21606/drs.2018.225 Luca
# -----
#
# Working on row 53: Horse, Butler or Elevator? Metaphors and enactment as a catalyst for exploring interaction with autonomous technology
# 10.21606/drs.2018.329 Helena
# -----
#
# Working on row 54: Editorial: Design for Subjective Wellbeing
# 10.21606/drs.2018.77 Rebecca
# -----
#
# Working on row 55: User Empowerment by Design: a new domestic electricity consumption model. A case study of young urban tenants
# 10.21606/drs.2018.470 Sagit
# -----
#
# Working on row 56: Requests from Companies and Requirements for Design Education in Brazil: where do they meet?
# 10.21606/drs.2018.535 Paulo Roberto Nicoletti
# -----
#
# Working on row 57: Perspective: the gist of public tender for service design
# 10.21606/drs.2018.367 Seungho
# -----
#
# Working on row 58: Catalysing Pathway Creation for Transition Governance
# 10.21606/drs.2018.448 Sampsa
# -----
#
# Working on row 59: Conversation: Design and sexism: assembling a community of care
# 10.21606/drs.2018.745 Tanveer
# -----
#
# Working on row 60: A Co-Experience Toolkit: investigating the issues of the pavement environment and the relationship with elderly pedestrians
# 10.21606/drs.2018.328 Lulu
# -----
#
# Working on row 61: Conversation: Shifting Perspectives of Aesthetics
# 10.21606/drs.2018.760 Monica
# -----
#
# Working on row 62: A Survey of Prosthetic Preferences in the UK and Greece
# 10.21606/drs.2018.232 Anna
# -----
#
# Working on row 63: Drawing as Notational Thinking in Architectural Design
# 10.21606/drs.2018.247 Otto
# -----
#
# Working on row 64: ‘One Over, One Under’: a dialogue between design and craft
# 10.21606/drs.2018.276 Can
# -----
#
# Working on row 65: The Co-archiving Toolbox – Designing conditions for diversity in public archives
# 10.21606/drs.2018.353 Elisabet M.
# -----
#
# Working on row 66: Conversation: Imagining critical practises in practise based design research: What is your ‘critical’ approach?
# 10.21606/drs.2018.765 Shana
# -----
#
# Working on row 67: Puerto Rico 2054: design pedagogy in a time of crisis
# 10.21606/drs.2018.351 Lesley-Ann
# -----
#
# Working on row 68: RTD in Landscape Architecture: a first State of the Art
# 10.21606/drs.2018.293 Sanda
# -----
#
# Working on row 69: Combining Craft and Digital Tools in Design Education for the General Public
# 10.21606/drs.2018.455 Ingri
# -----
#
# Working on row 70: Designing Play Equipment for Children with Cerebral Palsy: the context and design guidelines
# 10.21606/drs.2018.491 Ganna
# -----
#
# Working on row 71: Understanding How Design Action Plans Support the Strategic Use of Design
# 10.21606/drs.2018.538 Emilene
# -----
#
# Working on row 72: Changes in Design Research: sources and methods of idea generation in industrial design
# 10.21606/drs.2018.561 Ying
# -----
#
# Working on row 73: Data Exploration for Generative Design Research
# 10.21606/drs.2018.565 Peter
# -----
#
# Working on row 74: Tacit Synthesis: typography as research
# 10.21606/drs.2018.677 Jilian
# -----
#
# Working on row 75: Tegelen: supporting individual and group reflection through a dynamic, structured and tangible tool
# 10.21606/drs.2018.589 Yasemin
# -----
#
# Working on row 76: Journey Towards an Irish Design Strategy
# 10.21606/drs.2017.243 Anna
# -----
#
# Working on row 77: Design Insights and Opportunities from a Field Study to Digitally Enhance Microcredit Practices in Brazil
# 10.21606/drs.2018.339 Heloisa
# -----
#
# Working on row 78: Encouraging Physical Activity and Self-Enhancement in Women with Breast Cancer Through a Smart Bra
# 10.21606/drs.2018.437 Daphne
# -----
#
# Working on row 79: Training the Next Generation of Designers for a Sustainable Future: Action Research on the Circular Design Internship
# 10.21606/drs.2018.515 Yekta
# -----
#
# Working on row 80: Conversation: Design Education as a Catalyst for Change
# 10.21606/drs.2018.773 Donál
# -----
#
# Working on row 81: Editorial: Design, Research and Feminism(s)
# 10.21606/drs.2017.005 Kristina
# -----
#
# Working on row 82: Learning from Feminist Critiques of and Recommendations for Industrial Design
# 10.21606/drs.2018.355 Isabel
# -----
#
# Working on row 83: Design Expertise in Public and Social Innovation
# 10.21606/drs.2018.483 Mieke
# -----
#
# Working on row 84: Understanding Situated Energy Values in Rural Kenya
# 10.21606/drs.2018.669 Larissa
# -----
#
# Working on row 85: Textile Waste and Haptic Feedback for Wearable Robotics
# 10.21606/drs.2018.610 Hellen
# -----
#
# Working on row 86: Fostering Commonfare. Entanglements Between Participatory Design and Feminism
# 10.21606/drs.2018.557 Mariacristina
# -----
#
# Working on row 87: Towards a Circular Economy: exploring factors to repair broken electrical and electronics products by users with pro-environmental inclination
# 10.21606/drs.2018.556 Marie
# -----
#
# Working on row 88: Editorial: Designing for Transitions
# 10.21606/drs.2018.008 Joanna
# -----
#
# Working on row 89: Service Fictions Through Actant Switching
# 10.21606/drs.2018.486 Sarah-Marie
# -----
#
# Working on row 90: The Future of Heuristic Fossils
# 10.21606/drs.2018.612 Simon T.
# -----
#
# Working on row 91: Editorial: Not Just From the Centre
# 10.21606/drs.2017.006 Lesley-Ann
# -----
#
# Working on row 92: A Toolkit for Teaching the Design Process: A Case of Korean Elementary School Students
# 10.21606/drs.2018.548 Muhammad
# -----
#
# Working on row 93: Transformative Learning: co-design with communities’ collective imagery as data for social innovation
# 10.21606/drs.2018.360 Priscilla
# -----
#
# Working on row 94: Methods Across Borders: reflections of using design-led qualitative methods in Burkina Faso
# 10.21606/drs.2018.599 Adolphe
# -----
#
# Working on row 95: Surfing for Inspiration: digital inspirational material in design practice
# 10.21606/drs.2018.352 Janin
# -----
#
# Working on row 96: Design for Profit or Prosper
# 10.21606/drs.2018.278 Else
# -----
#
# Working on row 97: Embodied Design Methods as Catalyst for Industrial Service Design
# 10.21606/drs.2018.364 Titta
# -----
#
# Working on row 98: The Role(s) of Process Models in Design Practice
# 10.21606/drs.2018.289 Søren
# -----
#
# Working on row 99: Living Labs in Co-Creation and Sustainability as Strategies for Design Education
# 10.21606/drs.2018.267 Najla
# -----
#
# Working on row 100: Visual Materiality: crafting a new viscosity
# 10.21606/drs.2018.534 Maria
# -----
#
# Working on row 101: I-Wonder-How:A Method for Co-designing with Children in Design Education
# 10.21606/drs.2018.638 Sila
# -----
#
# Working on row 102: Building Relationships and Sustaining Dialogue Between Patients, Caregivers and Healthcare Practitioners: a design evaluation of digital platforms for ventricular assist device users
# 10.21606/drs.2018.639 Jessica Lea
# -----
#
# Working on row 103: Cascading Mentorship: Designing a Support Tool for Patients with Ventricular Assist Devices
# 10.21606/drs.2018.692 Mackenzie Norman
# -----
#
# Working on row 104: Editorial: Design, Technology and Society
# 10.21606/drs.2018.002 Daniel
# -----
#
# Working on row 105: A Study of Roles and Collaboration in the Development of Assistive Devices for People with Disabilities by Clinical Experts and Design Experts
# 10.21606/drs.2018.379 Agnes Jihae
# -----
#
# Working on row 106: Pedagogical Design Research for University Police Uniforms
# 10.21606/drs.2018.643 Brooke
# -----
#
# Working on row 107: Conversation: HAVE WE REACHED PEAK DESIGN THINKING? Are we entering a new paradigm for how it is used within practice and business?
# 10.21606/drs.2018.727 Michelle
# -----
#
# Working on row 108: Conversation: Divergence and convergence in graphic design and communication design
# 10.21606/drs.2018.771 Robert
# -----
#
# Working on row 109: Conversation: ‘Conversing WITH Materials’ -How do we converse with materials and other beings to co-design equitably?
# 10.21606/drs.2018.711 Jane
# -----
#
# Working on row 110: Experiential Characterization of Materials: toward a toolkit
# 10.21606/drs.2018.508 Serena
# -----
#
# Working on row 111: Align and Combine, Customer Journey Mapping and COM-B Analysis to Aid Decision-Making During the Design Process
# 10.21606/drs.20188.208 Olga
# -----
#
# Working on row 112: A Study on the Roles of Designers Co-Evolving with Tools
# 10.21606/drs.2018.533 Jeong-Sub
# -----
#
# Working on row 113: Engaging Qualities: factors affecting learner attention in online design studios
# 10.21606/drs.2018.326 Nicole
# -----
#
# Working on row 114: Culture-Orientated Food Design for Social Issue
# 10.21606/drs.2018.593 Yinman
# -----
#
# Working on row 115: Ethics in Design: pluralism and the case for justice in inclusive design
# 10.21606/drs.2018.221 Matteo
# -----
#
# Working on row 116: Prototyping Multispecies Environments: attentiveness and friction as modes of knowing
# 10.21606/drs.2018.546 Martin
# -----
#
# Working on row 117: Design for Future Retailing: an investigation into the changing status of city-basedretailers in the UK
# 10.21606/drs.2018.410 Yujia
# -----
#
# Working on row 118: Conversation: A Feminine Approach to Design
# 10.21606/drs.2018.721 Kate
# -----
#
# Working on row 119: Conversation: “Is Universal Design Dead?”: Creating inclusive user experience design methods
# 10.21606/drs.2018.790 Helen
# -----
#
# Working on row 120: Editorial: Experiential Knowledge in Collaborative Interdisciplinary Design Research
# 10.21606/drs.2018.012 Nithikul
# -----
#
# Working on row 121: Designer’s Emotions in the Design Process
# 10.21606/drs.2018.408 Monica
# -----
#
# Working on row 122: Distinctions Between the Communication of Experiential and Academic Design Knowledge: a linguistic analysis
# 10.21606/drs.2018.532 Yubo
# -----
#
# Working on row 123: Whole-to-Part-to-Whole: Co-Evolutionary and Integrative Design Approach
# 10.21606/drs.2018.213 Hernan
# -----
#
# Working on row 124: The Use of Philosophical Theories in Design: AResearch-Through-Design Case of Treatment Compliance
# 10.21606/drs.2018.231 Jonne
# -----
#
# Working on row 125: Beyond Accessible Aisles? Psychosocial Inclusivity of Shopping Experience: an ethnographic investigation
# 10.21606/drs.2018.462 Yonghun
# -----
#
# Working on row 126: Approaches for Capturing and Communicating Individual Narrative Timelines Reflecting Real Life (Retirement)
# 10.21606/drs.2018.517 Chris
# -----
#
# Working on row 127: Identifying the User in an Informal Trade Ecosystem
# 10.21606/drs.2018.674 Niti
# -----
#
# Working on row 128: Editorial: Design for Tangible, Embedded and Networked Technologies Special Interest Group (tentSIG)
# 10.21606/drs.2018.017 Sarah
# -----
#
# Working on row 129: Formgiving to Feminist Futures as Design Activism
# 10.21606/drs.2018.464 Maryam
# -----
#
# Working on row 130: Co-designing Behaviour Change in Healthcare
# 10.21606/drs.2018.317 Kieran
# -----
#
# Working on row 131: Editorial: Material-Enabled Changes in Design Research and Practice
# 10.21606/drs.2018.024 Elvin
# -----
#
# Working on row 132: Natural Materials – Nature of Materials
# 10.21606/drs.2018.273 Damla
# -----
#
# Working on row 133: How Materials Support Conceptual Blending in Ideation
# 10.21606/drs.2018.242 Michael Mose
# -----
#
# Working on row 134: Paradigm Shift in Design Education: An overview on issues and possibilities for change
# 10.21606/drs.2018.541 Hugo
# -----
#
# Working on row 135: Mybias: A web-based Tool to Overcome Designers’ Biases in Heterogeneous Design Teams
# 10.21606/drs.2018.445 Francesca
# -----
#
# Working on row 136: Editorial: The Role of Design in Open Innovation
# 10.21606/drs.2018.023 María Isabel
# -----
#
# Working on row 137: Exploring Lost and Found in Future Images of EnergyTransitions: towards a bridging practice of provoking and affirming design
# 10.21606/drs.2018.324 Mia
# -----
#
# Working on row 138: Design as a Catalyst for Sustainability Transitions
# 10.21606/drs.2018.292 Ayşe İdil
# -----
#
# Working on row 139: Seeking for Diversity among Young Users: the case of children's photography
# 10.21606/drs.2018.295 Sedef
# -----
#
# Working on row 140: Conversations: Editorial
# 10.21606/drs.2018.984 Sharon
# -----
#
# Working on row 141: Conversation: Lexicon Live: Performing the discursive space around keywords
# 10.21606/drs.2018.717 Liesbeth
# -----
#
# Working on row 142: Using the Product Impact Tool for Prospective Thinking
# 10.21606/drs.2018.262 Thomas
# -----
#
# Working on row 143: Editorial: Philosophical Tools in Design Research: from empirical turn to practical turn
# 10.21606/dma2018.004 Wouter
# -----
#
# Working on row 144: Philosophy of Technology x Design: the practical turn
# 10.21606/drs.2018.222 Wouter
# -----
#
# Working on row 145: Editorial: Designing for Diversity: Inclusive Design as a catalyst for change?
# 10.21606/drs.2018.014 Farnaz
# -----
#
# Working on row 146: How Consumers Read the Visual Presentation of Food Packaging Design in a Cross-cultural Context: a conceptual framework and case study
# 10.21606/drs.2018.260 Linna
# -----
#
# Working on row 147: Post-Series Design: a tool for catalysing the diffusion of personalisable design
# 10.21606/drs.2018.678 Viktor
# -----
#
# Working on row 148: How Design Thinking Offers Strategic Value to Micro-Enterprises
# 10.21606/drs.2018.434 Lee
# -----
#
# Working on row 149: Building the Foundation for a Design-Led Ambidexterity in a Medium-SizedTech Company
# 10.21606/drs.2018.401 Niya
# -----
#
# Working on row 150: Editorial: Designing with Data, Democratisation Through Data
# 10.21606/drs.2018.001 Nicola
# -----
#
# Working on row 151: Investigating Perceptions Related to Technology Acceptance & Stigma of Wearable Robotic Assistive Devices by Older Adults - Preliminary Findings
# 10.21606/drs.2018.477 Linda
# -----
#
# Working on row 152: Good Design-Driven Innovation
# 10.21606/drs.2018.648 Ehsan
# -----
#
# Working on row 153: Designing Idea Management Tools: three challenges
# 10.21606/drs.2018.404 Nanna
# -----
#
# Working on row 154: A Place to Be or, at Least, a Space to See: a qualitative inquiry on the experience and appreciation of extensive green roofs
# 10.21606/drs.2018.358 Caroline
# -----
#
# Working on row 155: Transition-oriented Futuring: integrated design fordecreased consumption amongst millennials
# 10.21606/drs.2018.512 Swati
# -----
#
# Working on row 156: Do-It-Yourself Medical Devices: exploring their potential futures through design fiction
# 10.21606/drs.2018.475 Michael
# -----
#
# Working on row 157: Turning Philosophy with a Speculative Lathe: object-oriented ontology, carpentry, and design fiction
# 10.21606/drs.2018.327 Joseph
# -----
#
# Working on row 158: Using Heterotopias to Characterise Interactions in Physical/Digital Spaces
# 10.21606/drs.2018.348 Haider Ali
# -----
#
# Working on row 159: Graphic Design Research: a cause for the concerned
# 10.21606/drs.2018.389 Robert George
# -----
#
# Working on row 160: Are Traditional NPD Processes Relevant to IoT Product and Service Development Activities? A Critical Examination
# 10.21606/drs.2018.244 Boyeun
# -----
#
# Working on row 161: Editorial: Design Innovation Management
# 10.21606/drs.2018.025 Erik
# -----
#
# Working on row 162: Design Research Opportunities in the Internet of Health Things: a review of reviews
# 10.21606/drs.2018.288 Emmanuel
# -----
#
# Working on row 163: A Qualitative Study on Turkish Medical Device Manufacturers and the Attention They Place on Human-Centred Design
# 10.21606/drs.2018.439 Nilay Gulfer
# -----
#
# Working on row 164: Editorial: Physical and Digital Materials in Creative Design Practice
# 10.21606/drs.2018.010 Kim
# -----
#
# Working on row 165: An Examination of Scholarly Critique in DRS Publications and Its Role as Catalyst for Community Building
# 10.21606/drs.2018.482 Jordan
# -----
#
# Working on row 166: Exploring the Interaction Between Lighting Variables and Information Transfer as a New Function of Lighting
# 10.21606/drs.2018.547 Jun
# -----
#
# Working on row 167: A Design Tool to Apply Distributed Manufacturing Principles to Sustainable Product-Service System Development
# 10.21606/drs.2018.485 Aine
# -----
#
# Working on row 168: Ethical Issues in Designing Interventions for Behavioural Change
# 10.21606/drs.2018.498 Gyuchan Thomas
# -----
#
# Working on row 169: A Vocabulary for Visions in Designing for Transitions
# 10.21606/drs.2018.558 Dan
# -----
#
# Working on row 170: Matching Data and Emotions for Designing Personalized Digital Experiences
# 10.21606/drs.2018.653 Myrthe
# -----
#
# Working on row 171: Rational Overrides: Influence Behaviour Beyond Nudging
# 10.21606/drs.2018.699 Anne
# -----
#
# Working on row 172: The Ideas Café: engaging the public in design research
# 10.21606/drs.2018.564 Arun
# -----
#
# Working on row 173: Persona Development in the Public Domain? Challenges to tackle
# 10.21606/drs.2018.392 Amber
# -----
#
# Working on row 174: Discovery DiDIY. An Immersive Gamified Activity to Explore the Potentialities of Digital Technology
# 10.21606/drs.2018.616 Marita
# -----
#
# Working on row 175: Repurposing Digital Methods for Human-Centered Design
# 10.21606/drs.2018.308 Donato
# -----
#
# Working on row 176: Designing InWith Black Box Technologies and PD
# 10.21606/drs.2018.296 Arthi
# -----
#
# Working on row 177: Developing Chilean Teaching Capability Through Design Thinking
# 10.21606/drs.2018.592 Catalina
# -----
#
# Working on row 178: An Ontology of Computational Tools for Design Activities
# 10.21606/drs.2018.456 Philippa
# -----
#
# Working on row 179: Conversation: Adventure: expedition to Pragmatism and Inventivism in the design situation
# 10.21606/drs.2018.796 Sander
# -----
#
# Working on row 180: Numeral Legibility and Visual Complexity
# 10.21606/drs.2018.246 Sofie
# -----
#
# Working on row 181: Co-creation in Professional Craft Practice
# 10.21606/drs.2018.256 Camilla
# -----
#
# Working on row 182: Conversation: Beyond black boxes: tackling artificial intelligence as a design material
# 10.21606/drs.2018.784 Aisling
# -----
#
# Working on row 183: The Fashion Collection Recalibrated - A Design Tool Furthering Sustainable Strategies
# 10.21606/drs.2018.53 Ulla
# -----
#
# Working on row 184: Conversation: How Complexity Science Can Support Design for Societal Change
# 10.21606/drs.2018.723 Ella
# -----
#
# Working on row 185: Annotated Portfolios as a Method to Analyse Interviews
# 10.21606/drs.2018.510 Marita
# -----
#
# Working on row 186: Conversation: THE SNUG: A Conversation about Design Research. Imagining, embodying, assembling
# 10.21606/drs.2018.708 Eva
# -----
#
# Working on row 187: Being-and-Becoming a Sustainable Practice
# 10.21606/drs.2018.490 Alicen
# -----
#
# Working on row 188: Developing a Design Toolkit for the Internet of Things
# 10.21606/drs.2018.447 Ilaria
# -----
#
# Working on row 189: Determinant Moments for the Design Management Occurrence in Fashion Industry
# 10.21606/drs.2018.279 Cláudia de Souza
# -----
#
# Working on row 190: Co-Located Team Designing: the oscillation between individual and social processes
# 10.21606/drs.2018.387 Bo T.
# -----
#
# Working on row 191: The Rhetorical Appeals in Interaction Design: decolonizing design for people of collectivist culture
# 10.21606/drs.2018.257 Octaviyanti Dwi
# -----
#
# Working on row 192: Sustainable Fashion Practices in the Soviet Union?
# 10.21606/drs.2018.309 Simona
# -----
#
# Working on row 193: On Connecting Form: explorations of a drawing method
# 10.21606/drs.2018.365 Dimitri
# -----
#
# Working on row 194: Editorial: Health and Wellbeing by Design
# 10.21606/drs.2018.019 Emmanuel
# -----
#
# Working on row 195: Editorial: Sustainable Design
# 10.21606/drs.2018.015 Rhoda
# -----
#
# Working on row 196: Editorial: Design Education: Catalysing Design Capability (PEDISG)
# 10.21606/drs.2018.021 Michael
# -----
#
# Working on row 197: Desert Drawing: from pigment to (Apple) pencil
# 10.21606/drs.2018.377 Nicola
# -----
#
# Working on row 198: Transdisciplinary Doctorates in the Making Disciplines
# 10.21606/drs.2018.591 Anne
# -----
#
# Working on row 199: Structuring Roles in Research Through Design Collaboration
# 10.21606/drs.2018.297 Froukje
# -----
#
# Working on row 200: Responsive Knit: the evolution of a programmable material system
# 10.21606/drs.2018.566 Jane
# -----
#
# Working on row 201: The Critical Design Exhibition: an epistemic space
# 10.21606/drs.2018.568 Gillian
# -----
#
# Working on row 202: The Search of the Unpredictable – the Process of Drawing
# 10.21606/drs.2018.609 Michael
# -----
#
# Working on row 203: Orienteering design through data: The data-driven design model
# 10.21606/drs.2018.539 Juan Carlo
# -----
#
# Working on row 204: DRS Conferences: barometer and mirror of theoretical reflection of design discipline
# 10.21606/drs.2018.647 Alejandra
# -----
#
# Working on row 205: Taking Care of Issues of Concern: feminist possibilities and the curation of Speculative and Critical Design
# 10.21606/drs.2018.632 Sarah
# -----
#
# Working on row 206: Drawing to See / Drawn to Seeing: Multimodal Reinterpretation in an Autonomous Drawing Machine
# 10.21606/drs.2018.687 Scott
# -----
#
# Working on row 207: Entangling, Oscillating, Frilux-ing: branding the art of design
# 10.21606/drs.2018.540 Sumit
# -----
#
# Working on row 208: Exploring the Pop-up Shop for Co-design Research
# 10.21606/drs.2018.457 Anja
# -----
#
# Working on row 209: Critique and Post-Critique in Social Innovation Projects: between speculation and realism
# 10.21606/drs.2018.529 Sissel
# -----
#
# Working on row 210: Pedagogic Power-Tools: knowing what was and what is, for what will be
# 10.21606/drs.2018.443 Glen
# -----
#
# Working on row 211: Design in Healthcare: challenges and opportunities
# 10.21606/drs.2018.318 Erez
# -----
#
# Working on row 212: Editorial: Design Education for the General Public
# 10.21606/drs.2018.020 Merete Liv
# -----
#
# Working on row 213: Digital, Analog, Discursive: knowledge practices and sense-making in design-build architecture
# 10.21606/drs.2018.438 Claire
# -----
#
# Working on row 214: Editorial: Tools of Design
# 10.21606/drs.2018.009 Philippa
# -----
#
# Working on row 215: Bookmaking as Critical and Feminist Practice of Design
# 10.21606/drs.2018.469 Ramia
# -----
#
# Working on row 216: Challenges in Barbadian Design Education – When Graphic Design & Product Development Collide
# 10.21606/drs.2018.333 Shelly
# -----
#
# Working on row 217: Reinventing Graphic Design Software by Bridging the Gap Between Graphical User Interfaces and Programming
# 10.21606/drs.2018.611 Nolwenn
# -----
#
# Working on row 218: The Ethics and Values of Visual Communication Strategies in European Advertisements in 21st Century Western and Islamic Culture
# 10.21606/drs.2017.241 Ilze
# -----
#
# Working on row 219: Understanding Design as a Catalyst to Engage Remote Couples in Designing for Long-Distance Relationships
# 10.21606/drs.2018.229 Hong
# -----
#
# Working on row 220: The Beauty of Making Hot Chocolate - an enquiry on designing for everyday rituals
# 10.21606/drs.2018.514 Pierre
# -----
#
# Working on row 221: Recognizing and Overcoming the Myths of Modernity
# 10.21606/drs.2018.468 Renata
# -----
#
# Working on row 222: The Road to Happiness is Paved with Playful Intentions
# 10.21606/drs.2018.390 Jesper
# -----
#
# Working on row 223: Design Processes and Co-Activity in Design Education
# 10.21606/drs.2018.574 Randi Veiteberg
# -----
#
# Working on row 224: Design for Multi-Dimensional Stages of Lymphoedema Self-Management
# 10.21606/drs.2018.549 Teksin
# -----
#
# Working on row 225: A Case Study to Explore Applicability of Creating Shared Value (CSV) into Design Practice
# 10.21606/drs.2018.223 Kyulee
# -----
#
# Working on row 226: Point of View Framework: describing the audience’s emotional connection to information design artifacts
# 10.21606/drs.2018.601 Soojin
# -----
#
# Working on row 227: Olivetti’s New Canaan Electronic Laboratory: when design meets computing
# 10.21606/drs.2018.656 ROCHA
# -----
#
# Working on row 228: The Role of the Designer in Public Discourse –A critical discourse analysis of a medical brochure for diabetes patients
# 10.21606/drs.2018.402 Julia
# -----
#
# Working on row 229: The Emerging Transition Design Approach
# 10.21606/drs.2018.210 Terry
# -----
#
# Working on row 230: Change Matters: theories of postdigital textiles and material design
# 10.21606/drs.2018.621 Elaine
# -----
#
# Working on row 231: Materials Liaisons: facilitating communication in Design-Driven Material Innovation (DDMI) projects
# 10.21606/drs.2018.446 Rosie
# -----
#
# Working on row 232: Reframing Design Problems Within Women’s Health
# 10.21606/drs.2018.337 Sarah
# -----
#
# Working on row 233: Data Sensification: beyond representation modality, toward encoding data in experience
# 10.21606/drs.2018.238 Trevor
# -----
#
# Working on row 234: Does Feedback from This Device Change Unhealthy habits? Lessons from my PhD project
# 10.21606/drs.2018.306 Sander
# -----
#
# Working on row 235: Understanding the Evaluation of New Products Through a Dual-Process Perspective
# 10.21606/drs.2018.217 Anders
# -----
#
# Working on row 236: The Design Laboratory. A Review of Five Design Education Programmes
# 10.21606/drs.2018.272 Gert
# -----
#
# Working on row 237: Socio-Cultural Factors in Diabetes Care in South Korea
# 10.21606/drs.2018.585 Young-ae
# -----
#
# Working on row 238: Editorial: Design for Behaviour Change
# 10.21606/drs.2018.016 Edward
# -----
#
# Working on row 239: A Case for Caribbean Design Principles
# 10.21606/drs.2018.522 Debbie-Ann
# -----
#
# Working on row 240: Designers by Any Other Name: exploring the sociomaterial practices of vernacular garment menders
# 10.21606/drs.2018.495 Marium
# -----
#
# Working on row 241: ‘Being Cultural’ Versus‘Cultural Beings’ –general design education
# 10.21606/drs.2018.542 Ingvild
# -----
#
# Working on row 242: Design Justice: towards an intersectional feminist framework for design theory and practice
# 10.21606/drs.2018.679 Sasha
# -----
#
# Working on row 243: Social Innovation by Design in Mobile Healthcare for Sleep Disorders
# 10.21606/drs.2018.264 Marie-Julie
# -----
#
# Working on row 244: Examining the Professional Codes of Design Organisations
# 10.21606/drs.2018.493 Peter
# -----
#
# Working on row 245: A Framework to Maximise Design Knowledge Exchange
# 10.21606/drs.2018.630 Kathryn
# -----
#
# Working on row 246: Scenes of Writing
# 10.21606/drs.2018.598 Anne
# -----
#
# Working on row 247: The View from Within: Design’s Voyage to Get a Seat at the Strategy Table
# 10.21606/drs.2018.398 Suzan
# -----
#
# Working on row 248: Design for Self-inclusion: supporting emotional capability
# 10.21606/drs.2018.628 Stella
# -----
#
# Working on row 249: Embodied Knowledge in a Community Adaptive Practice
# 10.21606/drs.2018.696 Sucharita
# -----
#
# Working on row 250: Augmenting Low Investment Learning Styles
# 10.21606/drs.2018.227 Kevin
# -----
#
# Working on row 251: “All about Love”: How would bell hooks teach fashion design?
# 10.21606/drs.2018.665 Tanveer
# ====
#  ALL DONE

# %% [markdown]
# # 06 - Save XML

# %%
xml_string = etree.tostring(doi_batch, pretty_print=True, xml_declaration=True, encoding="utf-8").decode("utf-8")

output_file = f"{DATA_FILE_NAME}.xml"
# Open the file in write mode and save the XML string
with open(output_file, "w", encoding="utf-8") as f:
    f.write(xml_string)

print(f"XML has been saved to {output_file}")
# Out:
# XML has been saved to drs2018.xml
