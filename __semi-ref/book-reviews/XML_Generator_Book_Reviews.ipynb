# %% [markdown]
# # XML Generator for CrossRef
#
# This notebook generates the XML file for CrossRef using the output from the DL Batch Revise Export.
#
# For this one we're following the example metadata for Reports: [https://gitlab.com/crossref/schema/-/blob/master/best-practice-examples/report.5.3.0.xml](https://gitlab.com/crossref/schema/-/blob/master/best-practice-examples/report.5.3.0.xml)

# %%
import pandas as pd
from lxml import etree
from datetime import datetime

# %% [markdown]
# ## VARIABLES
#
# These are the variables you have to modify before you run the notebook.

# %%
# VARIABLES AND PARAMETERS YOU HAVE TO SET EVERY RUN.
today = datetime.now()

SUBMISSION_TIMESTAMP = today.strftime("%Y%m%d%H%M%S") + "0000"

CSV_IN_FILE_NAME = "book_reviews"

# %% [markdown]
# ## Generate the Root Element

# %%
# Create a function to check the state of XML at any point:

def view_xml_result():
    # Pretty-print the XML
    xml_string = etree.tostring(doi_batch, pretty_print=True, xml_declaration=True, encoding="utf-8").decode("utf-8")

    # Print the formatted XML
    print(xml_string)

# %%
# Define namespaces without 'xmlns:' in the keys
namespaces = {
    "xsi": "http://www.w3.org/2001/XMLSchema-instance",
    None: "http://www.crossref.org/schema/5.3.0",  # Default namespace
    "jats": "http://www.ncbi.nlm.nih.gov/JATS1",
    "fr": "http://www.crossref.org/fundref.xsd",
    "mml": "http://www.w3.org/1998/Math/MathML",
}

# Create the root element with namespaces
doi_batch = etree.Element("doi_batch", nsmap=namespaces)

doi_batch.set("version", "5.3.0")

doi_batch.set(
    "{http://www.w3.org/2001/XMLSchema-instance}schemaLocation",
    "http://www.crossref.org/schema/5.3.0 https://www.crossref.org/schemas/crossref5.3.0.xsd"
)

# Add head and body
head = etree.SubElement(doi_batch, "head")
body = etree.SubElement(doi_batch, "body")

view_xml_result()
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <doi_batch xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.crossref.org/schema/5.3.0" xmlns:jats="http://www.ncbi.nlm.nih.gov/JATS1" xmlns:fr="http://www.crossref.org/fundref.xsd" xmlns:mml="http://www.w3.org/1998/Math/MathML" version="5.3.0" xsi:schemaLocation="http://www.crossref.org/schema/5.3.0 https://www.crossref.org/schemas/crossref5.3.0.xsd">
#   <head/>
#   <body/>
# </doi_batch>

# %% [markdown]
# ## Populate the `head`

# %%
today_short = today.strftime("%y%m%d")

doi_batch_id = etree.SubElement(head, "doi_batch_id").text = f"reviews.{today_short}"
timestamp = etree.SubElement(head, "timestamp").text = SUBMISSION_TIMESTAMP

depositor = etree.SubElement(head, "depositor")
depositor_name = etree.SubElement(depositor, "depositor_name").text = "desres:desres"
email_address = etree.SubElement(depositor, "email_address").text = ("dl@designresearchsociety.org")

registrant = etree.SubElement(head, "registrant").text = "Digital Library"

view_xml_result()
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <doi_batch xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.crossref.org/schema/5.3.0" xmlns:jats="http://www.ncbi.nlm.nih.gov/JATS1" xmlns:fr="http://www.crossref.org/fundref.xsd" xmlns:mml="http://www.w3.org/1998/Math/MathML" version="5.3.0" xsi:schemaLocation="http://www.crossref.org/schema/5.3.0 https://www.crossref.org/schemas/crossref5.3.0.xsd">
#   <head>
#     <doi_batch_id>reviews.250304</doi_batch_id>
#     <timestamp>202503041838100000</timestamp>
#     <depositor>
#       <depositor_name>desres:desres</depositor_name>
#       <email_address>dl@designresearchsociety.org</email_address>
#     </depositor>
#     <registrant>Digital Library</registrant>
#   </head>
#   <body/>
# </doi_batch>

# %% [markdown]
# # Populating the `body`
#
# Body has a series of `report-paper` elements. Each element has the following structure:
#
# - `contributors`
#     - `person_name`
#         - `given_name`
#         - `surname`
#         - `affiliations`
#             - `institution`
#                 - `institution_name`
# - `titles`
#     - `title`
# - `edition_number` == 0
# - `publication_date`
#     - `month`
#     - `day`
#     - `year`
# - `doi_data`
#     - `doi`
#     - `resource`
#
#
# We'll try to respect this and see if we have to add more info for it to pass.
#
# ---

# %% [markdown]
# ## Creating Report Papers.
#
#
# First we load the CSV file and remove the unneeded columns. For our purposes we need the following columns:
#
# - `author1_fname`
# - `author1_mname`
# - `author1_lname`
# - `author1_suffix`
# - `author1_institution`
# - `title`
# - `publication_date`
# - `doi`
# - `calc_url`

# %%
# LOAD CSV FILE
df = pd.read_csv(CSV_IN_FILE_NAME+".csv", sep=",")


df_core = df[["title", "publication_date", "doi", "calc_url", "author1_fname", "author1_mname", "author1_lname", "author1_suffix", "author1_institution"]]
df_core = df_core.fillna('').astype(str)
df_core.head(10)
# Out:
#                                                title  publication_date  \
# 0  Review of The Legal Design Book: Doing Law in ...  2022-03-28 00:00
# 1  Review of Design, Empathy, Interpretation: Tow...  2023-10-27 00:00
# 2  Review of Design for a Better World: Meaningfu...  2023-11-08 00:00
# 3           Review of Design is Power: The Dark Side  2025-01-01 00:00
# 4  Review of Design Social Change: take action, w...  2024-02-01 00:00
# 5      Review of Designing for Sex and Gender Equity  2024-04-01 00:00
# 6  Review of Bioprotopia: Designing the Built Env...  2024-05-01 00:00
# 7     Review of Meaningful Stuff. Design That Lasts.  2024-06-01 00:00
# 8  Review of Teaching Graphic Design: Approaches,...  2024-06-01 00:00
# 9  Review of Visual Methods for Digital Research:...  2024-10-01 00:00
#
#                  doi                                           calc_url  \
# 0  10.21606/wsbr.001  https://dl.designresearchsociety.org/drs-book-...
# 1  10.21606/wsbr.002  https://dl.designresearchsociety.org/drs-book-...
# 2  10.21606/wsbr.003  https://dl.designresearchsociety.org/drs-book-...
# 3  10.21606/wsbr.004  https://dl.designresearchsociety.org/drs-book-...
# 4  10.21606/wsbr.005  https://dl.designresearchsociety.org/drs-book-...
# 5  10.21606/wsbr.006  https://dl.designresearchsociety.org/drs-book-...
# 6  10.21606/wsbr.007  https://dl.designresearchsociety.org/drs-book-...
# 7  10.21606/wsbr.008  https://dl.designresearchsociety.org/drs-book-...
# 8  10.21606/wsbr.009  https://dl.designresearchsociety.org/drs-book-...
# 9  10.21606/wsbr.010  https://dl.designresearchsociety.org/drs-book-...
#
#   author1_fname author1_mname   author1_lname author1_suffix  \
# 0      Mohammed                      Al Rezan
# 1         Jules     Rochielle         Sievert
# 2      Shriyash                         Shete
# 3      Samantha                          Osys
# 4       Michael                        Kibedi
# 5     Annapaola                       Vacanti
# 6         Gozde         Damla  Turhan-Haskara
# 7        Niklas       Hermann           Henke
# 8         Ellen                   Christensen
# 9         Gerry                       Derksen
#
#                            author1_institution
# 0  Al-Imam Mohamed Ibn Saud Islamic University
# 1                      Northeastern University
# 2
# 3                          The Open University
# 4
# 5                   Università Iuav di Venezia
# 6                Izmir University of Economics
# 7                       University of Grenoble
# 8               San Francisco State University
# 9                           Clemson University

# %% [markdown]
# Now we use this data to create each `report-paper` element in the XML.

# %%
# Clean body so we can try again
body.clear()

# Create element for each row in the table
for index, row in df_core.iterrows():
    print(f"Working on row {index}: {row['title']}")


    # Create <report-paper> and <report-paper_metadata>.
    report_paper = etree.SubElement(body, "report-paper")
    report_paper_metadata = etree.SubElement(report_paper, "report-paper_metadata",language="en")

    # Create contributor
    contributor = etree.SubElement(report_paper_metadata, "contributors")

    # contributor - Add person name
    person_name = etree.SubElement(contributor, "person_name", sequence="first", contributor_role="author")
    given_name = etree.SubElement(person_name, "given_name").text = row['author1_fname']
    surname = etree.SubElement(person_name, "surname").text = row['author1_lname']

    # contributor - Add affiliation
    affiliations = etree.SubElement(person_name, "affiliations")
    institution = etree.SubElement(affiliations, "institution")
    institution_name = etree.SubElement(institution, "institution_name").text = (row['author1_institution'].strip() or "Design Research Society")

    # Create titles
    titles = etree.SubElement(report_paper_metadata, "titles")
    title = etree.SubElement(titles, "title").text = row['title']

    # Create edition_number
    edition_number = etree.SubElement(report_paper_metadata, "edition_number").text = "0"

    # Create publication_date
    publication_date = etree.SubElement(report_paper_metadata, "publication_date")

    # publication_date - clean date
    date_part = row['publication_date'].split(' ')[0]
    year_data, month_data, day_data = date_part.split('-')

    # publication_date - add elements
    month = etree.SubElement(publication_date, "month").text = month_data
    day = etree.SubElement(publication_date, "day").text = day_data
    year = etree.SubElement(publication_date, "year").text = year_data


    # Create doi_data
    doi_data = etree.SubElement(report_paper_metadata, "doi_data")

    # doi_data - add elements
    doi = etree.SubElement(doi_data, "doi").text = row["doi"].replace("doi.org/", "")
    resource = etree.SubElement(doi_data, "resource").text = row["calc_url"]


print("\n\n\n")
view_xml_result()
# Out:
# Working on row 0: Review of The Legal Design Book: Doing Law in the 21st Century
# Working on row 1: Review of Design, Empathy, Interpretation: Toward Interpretive Design Research
# Working on row 2: Review of Design for a Better World: Meaningful, Sustainable, Humanity Centered
# Working on row 3: Review of Design is Power: The Dark Side
# Working on row 4: Review of Design Social Change: take action, work toward equity, and challenge the status quo
# Working on row 5: Review of Designing for Sex and Gender Equity
# Working on row 6: Review of Bioprotopia: Designing the Built Environment with Living Organisms
# Working on row 7: Review of Meaningful Stuff. Design That Lasts.
# Working on row 8: Review of Teaching Graphic Design: Approaches, Insights, the Role of Listening, and 24 Interviews with Inspirational Educators
# Working on row 9: Review of Visual Methods for Digital Research: An Introduction
# Working on row 10: Review of Design Thinking and Other Approaches—How Different Disciplines See, Think and Act
# Working on row 11: Review of Breaking the Bronze Ceiling: Women, Memory, and Public Space
# Working on row 12: Review of Creative Design and Innovation: How to produce successful products and buildings
# Working on row 13: Review of Transforming Higher Education with Human-Centered Design
# Working on row 14: Review of Governable Spaces: Democratic Design for Online Life
# Working on row 15: Review of Craft and Design Practice from an Embodied Perspective
# Working on row 16: Review of Crises, Creativity and Innovation
#
#
#
#
# <?xml version='1.0' encoding='utf-8'?>
# <doi_batch xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.crossref.org/schema/5.3.0" xmlns:jats="http://www.ncbi.nlm.nih.gov/JATS1" xmlns:fr="http://www.crossref.org/fundref.xsd" xmlns:mml="http://www.w3.org/1998/Math/MathML" version="5.3.0" xsi:schemaLocation="http://www.crossref.org/schema/5.3.0 https://www.crossref.org/schemas/crossref5.3.0.xsd">
#   <head>
#     <doi_batch_id>reviews.250304</doi_batch_id>
#     <timestamp>202503041838100000</timestamp>
#     <depositor>
#       <depositor_name>desres:desres</depositor_name>
#       <email_address>dl@designresearchsociety.org</email_address>
#     </depositor>
#     <registrant>Digital Library</registrant>
#   </head>
#   <body>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Mohammed</given_name>
#             <surname>Al Rezan</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>Al-Imam Mohamed Ibn Saud Islamic University</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of The Legal Design Book: Doing Law in the 21st Century</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>03</month>
#           <day>28</day>
#           <year>2022</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.001</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/3</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Jules</given_name>
#             <surname>Sievert</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>Northeastern University</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Design, Empathy, Interpretation: Toward Interpretive Design Research</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>10</month>
#           <day>27</day>
#           <year>2023</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.002</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/2</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Shriyash</given_name>
#             <surname>Shete</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>Design Research Society</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Design for a Better World: Meaningful, Sustainable, Humanity Centered</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>11</month>
#           <day>08</day>
#           <year>2023</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.003</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/1</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Samantha</given_name>
#             <surname>Osys</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>The Open University</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Design is Power: The Dark Side</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>01</month>
#           <day>01</day>
#           <year>2025</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.004</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/4</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Michael</given_name>
#             <surname>Kibedi</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>Design Research Society</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Design Social Change: take action, work toward equity, and challenge the status quo</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>02</month>
#           <day>01</day>
#           <year>2024</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.005</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/5</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Annapaola</given_name>
#             <surname>Vacanti</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>Università Iuav di Venezia</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Designing for Sex and Gender Equity</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>04</month>
#           <day>01</day>
#           <year>2024</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.006</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/6</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Gozde</given_name>
#             <surname>Turhan-Haskara</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>Izmir University of Economics</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Bioprotopia: Designing the Built Environment with Living Organisms</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>05</month>
#           <day>01</day>
#           <year>2024</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.007</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/7</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Niklas</given_name>
#             <surname>Henke</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>University of Grenoble</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Meaningful Stuff. Design That Lasts.</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>06</month>
#           <day>01</day>
#           <year>2024</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.008</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/8</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Ellen</given_name>
#             <surname>Christensen</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>San Francisco State University</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Teaching Graphic Design: Approaches, Insights, the Role of Listening, and 24 Interviews with Inspirational Educators</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>06</month>
#           <day>01</day>
#           <year>2024</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.009</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/9</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Gerry</given_name>
#             <surname>Derksen</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>Clemson University</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Visual Methods for Digital Research: An Introduction</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>10</month>
#           <day>01</day>
#           <year>2024</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.010</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/10</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Maithili</given_name>
#             <surname>Mishra</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>Design Research Society</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Design Thinking and Other Approaches—How Different Disciplines See, Think and Act</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>10</month>
#           <day>01</day>
#           <year>2024</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.011</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/11</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Rukmini</given_name>
#             <surname>Swaminathan</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>The University Of Michigan</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Breaking the Bronze Ceiling: Women, Memory, and Public Space</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>11</month>
#           <day>01</day>
#           <year>2024</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.012</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/12</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Tomás</given_name>
#             <surname>García Ferrari</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>University of Waikato, New Zealand</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Creative Design and Innovation: How to produce successful products and buildings</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>12</month>
#           <day>01</day>
#           <year>2024</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.013</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/13</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Vu</given_name>
#             <surname>Quyen</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>University of Economics Ho Chi Minh City</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Transforming Higher Education with Human-Centered Design</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>12</month>
#           <day>18</day>
#           <year>2024</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.014</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/15</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Rachel</given_name>
#             <surname>Wood</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>The Open University</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Governable Spaces: Democratic Design for Online Life</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>01</month>
#           <day>01</day>
#           <year>2025</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.015</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/14</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Phil</given_name>
#             <surname>Jones</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>Bournemouth University</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Craft and Design Practice from an Embodied Perspective</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>02</month>
#           <day>01</day>
#           <year>2025</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.016</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/16</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#     <report-paper>
#       <report-paper_metadata language="en">
#         <contributors>
#           <person_name sequence="first" contributor_role="author">
#             <given_name>Erica</given_name>
#             <surname>Holeman</surname>
#             <affiliations>
#               <institution>
#                 <institution_name>University of North Texas</institution_name>
#               </institution>
#             </affiliations>
#           </person_name>
#         </contributors>
#         <titles>
#           <title>Review of Crises, Creativity and Innovation</title>
#         </titles>
#         <edition_number>0</edition_number>
#         <publication_date>
#           <month>02</month>
#           <day>01</day>
#           <year>2024</year>
#         </publication_date>
#         <doi_data>
#           <doi>10.21606/wsbr.017</doi>
#           <resource>https://dl.designresearchsociety.org/drs-book-reviews/17</resource>
#         </doi_data>
#       </report-paper_metadata>
#     </report-paper>
#   </body>
# </doi_batch>

# %% [markdown]
# SAVE THE XML

# %%
xml_string = etree.tostring(doi_batch, pretty_print=True, xml_declaration=True, encoding="utf-8").decode("utf-8")

output_file = f"{CSV_IN_FILE_NAME}.xml"
# Open the file in write mode and save the XML string
with open(output_file, "w", encoding="utf-8") as f:
    f.write(xml_string)

print(f"XML has been saved to {output_file}")
# Out:
# XML has been saved to book_reviews.xml
