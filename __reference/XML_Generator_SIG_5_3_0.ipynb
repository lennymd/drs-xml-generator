# %% [markdown]
# # XML Generator for CrossRef
#
# This notebook generates the XML file for CrossRef using the output from the DL Batch Revise Export.

# %%
import pandas as pd
from lxml import etree
from datetime import datetime

# %% [markdown]
# # CONFIGURATION
#
# These are the variables to set manually for each run.

# %%
DATA_FILE_NAME = "drs2018"

# %% [markdown]
# # FUNCTIONS TO RUN THINGS

# %%
# Create a function to check the state of XML at any point:

def view_xml_result():
    # Pretty-print the XML
    xml_string = etree.tostring(doi_batch, pretty_print=True, xml_declaration=True, encoding="utf-8").decode("utf-8")

    # Print the formatted XML
    print(xml_string)

# %% [markdown]
# ## VARIABLES
#
# These are the variables you have to modify before you run the notebook.

# %%
# VARIABLES AND PARAMETERS YOU HAVE TO SET
SUBMISSION_TIMESTAMP = "20241213194100000"


PUBLICATION_DAY = "12"
PUBLICATION_MONTH = "01"
PUBLICATION_YEAR = "2023"
CONFERENCE_DATE = f"{PUBLICATION_DAY}/{PUBLICATION_MONTH}/{PUBLICATION_YEAR}"

CONFERENCE_NAME = "LearnXDesign 2023"
PROCEEDINGS_TITLE = "LearnXDesign 2023"
CONFERENCE_ACRONYM = "LearnXDesign 2023"
ISBN = "9781912294619"

CONFERENCE_VOLUME_DOI = "10.21606/drslxd.2024.001"
CONFERENCE_VOLUME_URL = "https://dl.designresearchsociety.org/conference-volumes/61/"

CSV_FILE_NAME = "lxd2023.csv"
OUT_FILE_NAME = "241213-lxd2023"

MAX_AUTHORS = 20  # Used for creating authors

# %% [markdown]
# ## Generate the Root Element

# %%
namespaces = {
    'xsi': 'http://www.w3.org/2001/XMLSchema-instance'
}

doi_batch = ET.Element(
    "doi_batch",
    version="4.8.0",
    xmlns="http://www.crossref.org/schema/4.8.0",
)

# Manually set the xsi:schemaLocation attribute
doi_batch.set("xmlns:xsi", "http://www.w3.org/2001/XMLSchema-instance")
doi_batch.set("xsi:schemaLocation", "http://www.crossref.org/schema/4.8.0 http://www.crossref.org/schema/deposit/crossref4.8.0.xsd")


head = ET.SubElement(doi_batch, "head")
body = ET.SubElement(doi_batch, "body")
conference = ET.SubElement(body, "conference")
print(ET.tostring(doi_batch, encoding='utf8').decode('utf8'))
# Out:
# <?xml version='1.0' encoding='utf8'?>
# <doi_batch version="4.8.0" xmlns="http://www.crossref.org/schema/4.8.0" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.crossref.org/schema/4.8.0 http://www.crossref.org/schema/deposit/crossref4.8.0.xsd"><head /><body><conference /></body></doi_batch>

# %% [markdown]
# ## Populate the `head`

# %%
# Set up the head of the XML
doi_batch_id = ET.SubElement(head, "doi_batch_id").text = CONFERENCE_NAME
timestamp = ET.SubElement(head, "timestamp").text = SUBMISSION_TIMESTAMP
depositor = ET.SubElement(head, "depositor")

# The following values are hard-coded
depositor_name = ET.SubElement(depositor, "depositor_name").text = "desres:desres"
email_address = ET.SubElement(depositor, "email_address").text = ("dl@designresearchsociety.org")
registrant = ET.SubElement(head, "registrant").text = "Digital Library"

# %% [markdown]
# # Populating the `body`
#
# Body has a `conference` element inside and in there we have to have:
#
# - `event_metadata`
# - `proceedings_metadata`
# - every `conference_paper`

# %%
# EVENT_METADATA
event_metadata = ET.SubElement(conference, "event_metadata")
conference_name = ET.SubElement(event_metadata, "conference_name").text = CONFERENCE_NAME
conference_acronym = ET.SubElement(event_metadata, "conference_acronym").text = CONFERENCE_ACRONYM
conference_date = ET.SubElement(event_metadata, "conference_date").text = CONFERENCE_DATE


# PROCEEDINGS_METADATA
proceedings_metadata = ET.SubElement(conference, "proceedings_metadata")
proceedings_title = ET.SubElement(proceedings_metadata, "proceedings_title").text = PROCEEDINGS_TITLE

publisher = ET.SubElement(proceedings_metadata, "publisher")
publisher_name = ET.SubElement(publisher, "publisher_name").text = "Design Research Society"

publication_date1 = ET.SubElement(proceedings_metadata, "publication_date", media_type="online")
month = ET.SubElement(publication_date1, "month").text = PUBLICATION_MONTH
day = ET.SubElement(publication_date1, "day").text = PUBLICATION_DAY
year = ET.SubElement(publication_date1, "year").text = PUBLICATION_YEAR

isbn = ET.SubElement(proceedings_metadata, "isbn").text = ISBN

doi_data1 = ET.SubElement(proceedings_metadata, "doi_data")
doi = ET.SubElement(doi_data1, "doi").text = CONFERENCE_VOLUME_DOI
resource = ET.SubElement(doi_data1, "resource").text = CONFERENCE_VOLUME_URL

# %% [markdown]
# ## Creating Conference Papers
#
# We have code for this to process the CSV File and create the data for each row. One row = 1 paper.

# %%
# Load the right CSV file
df = pd.read_csv(CSV_FILE_NAME, sep=",")
df.head()
# Out:
#                                                title  shortname  \
# 0                                Unfixing the studio        NaN
# 1  The Work of Untutored Designers & the Future o...        NaN
# 2  Inviting Curiosity: A Framework for Creating M...        NaN
# 3        User Data: A North Star in Teaching Methods        NaN
# 4  Competencies and Skills for Designers of Infor...        NaN
#
#                                         editor_names  orcid  document_type  \
# 0  Derek Jones, Naz Borekci, Violeta Clemente, Ja...    NaN            NaN
# 1  Derek Jones, Naz Borekci, Violeta Clemente, Ja...    NaN            NaN
# 2  Derek Jones, Naz Borekci, Violeta Clemente, Ja...    NaN            NaN
# 3  Derek Jones, Naz Borekci, Violeta Clemente, Ja...    NaN            NaN
# 4  Derek Jones, Naz Borekci, Violeta Clemente, Ja...    NaN            NaN
#
#   abstract keywords                                   conference_title  \
# 0      NaN      NaN  The 7th International Conference for Design Ed...
# 1      NaN      NaN  The 7th International Conference for Design Ed...
# 2      NaN      NaN  The 7th International Conference for Design Ed...
# 3      NaN      NaN  The 7th International Conference for Design Ed...
# 4      NaN      NaN  The 7th International Conference for Design Ed...
#
#                         doi                                  doi_link  ...  \
# 0  10.21606/drslxd.2024.057  https://doi.org/10.21606/drslxd.2024.057  ...
# 1  10.21606/drslxd.2024.086  https://doi.org/10.21606/drslxd.2024.086  ...
# 2  10.21606/drslxd.2024.105  https://doi.org/10.21606/drslxd.2024.105  ...
# 3  10.21606/drslxd.2024.010  https://doi.org/10.21606/drslxd.2024.010  ...
# 4  10.21606/drslxd.2024.013  https://doi.org/10.21606/drslxd.2024.013  ...
#
#    author16_mname  author16_lname author16_suffix author16_email  \
# 0             NaN             NaN             NaN            NaN
# 1             NaN             NaN             NaN            NaN
# 2             NaN             NaN             NaN            NaN
# 3             NaN             NaN             NaN            NaN
# 4             NaN             NaN             NaN            NaN
#
#   author16_institution author16_is_corporate  \
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
#
#                                             calc_url context_key  \
# 0  https://dl.designresearchsociety.org/learnxdes...    36756083
# 1  https://dl.designresearchsociety.org/learnxdes...    36756084
# 2  https://dl.designresearchsociety.org/learnxdes...    36756085
# 3  https://dl.designresearchsociety.org/learnxdes...    36756142
# 4  https://dl.designresearchsociety.org/learnxdes...    36756143
#
#                                         issue     ctmtime
# 0  learnxdesign/learnxdesign2023/visualpapers  1710765013
# 1  learnxdesign/learnxdesign2023/visualpapers  1710765016
# 2  learnxdesign/learnxdesign2023/visualpapers  1710765013
# 3     learnxdesign/learnxdesign2023/casestudy  1710765015
# 4     learnxdesign/learnxdesign2023/casestudy  1710765014
#
# [5 rows x 140 columns]

# %% [markdown]
# ### Drop columns

# %%
# Drop columns that are not needed at all
df_dropped_first = df.drop(
    columns=[
        "city",
        "shortname",
        "editor_names",
        "orcid",
        "document_type",
        "abstract",
        "keywords",
        "comments",
        "conference_title",
        "doi_link",
        "custom_citation",
        "distribution_license",
        "conference_track",
        "conference_dates",
        "start_date",
        "end_date",
        "city",
        "country",
        "topics",
        "disciplines",
        "fulltext_url",
        "do_not_feature_this_article",
        "update_reason",
        "context_key",
        "issue",
        "ctmtime",
    ]
)


# Drop columns that are not needed and related to authors.
columns_to_drop = df_dropped_first.filter(
    regex=r"^author\d+_(email|suffix|mname|is_corporate)"
).columns

df_working = df_dropped_first.drop(columns=columns_to_drop)
print(df_working.columns)
# Out:
# Index(['title', 'doi', 'author1_fname', 'author1_lname', 'author1_institution',
#        'author2_fname', 'author2_lname', 'author2_institution',
#        'author3_fname', 'author3_lname', 'author3_institution',
#        'author4_fname', 'author4_lname', 'author4_institution',
#        'author5_fname', 'author5_lname', 'author5_institution',
#        'author6_fname', 'author6_lname', 'author6_institution',
#        'author7_fname', 'author7_lname', 'author7_institution',
#        'author8_fname', 'author8_lname', 'author8_institution',
#        'author9_fname', 'author9_lname', 'author9_institution',
#        'author10_fname', 'author10_lname', 'author10_institution',
#        'author11_fname', 'author11_lname', 'author11_institution',
#        'author12_fname', 'author12_lname', 'author12_institution',
#        'author13_fname', 'author13_lname', 'author13_institution',
#        'author14_fname', 'author14_lname', 'author14_institution',
#        'author15_fname', 'author15_lname', 'author15_institution',
#        'author16_fname', 'author16_lname', 'author16_institution', 'calc_url'],
#       dtype='object')

# %% [markdown]
# ### Process cleaned DF

# %%
# Two helper functions for processing authors

def create_person_element(sequence, first_name, last_name, institution):
    person = ET.Element("person_name", sequence=sequence, contributor_role="author")
    ET.SubElement(person, "given_name").text = first_name
    ET.SubElement(person, "surname").text = last_name
    affiliation = ET.SubElement(person, "affiliation").text = institution
    return person

def add_authors(contributors, row):
    for i in range(1, 7):  # Adjust if you have an idea of the typical max authors
        fname_col = f"author{i}_fname"
        lname_col = f"author{i}_lname"
        inst_col = f"author{i}_institution"

        # Check if the first name is empty; if so, break the loop
        if pd.isna(row[fname_col]):
            break

        # Add author only if all fields are non-empty
        if pd.notna(row[lname_col]) and pd.notna(row[inst_col]):
            sequence = "first" if i == 1 else "additional"
            contributors.append(
                create_person_element(
                    sequence, row[fname_col], row[lname_col], row[inst_col]
                )
            )

# %%
# Create element for each row in the table
for index, row in df_working.iterrows():
    print(f"Working on row {index}: {row['title']}")

    # Create conference_paper element
    # conference = ET.SubElement(body, "conference", content_type="proceedings
    conference_paper = ET.SubElement(
        conference, "conference_paper", publication_type="full_text"
    )

    # add contributors
    contributors = ET.SubElement(conference_paper, "contributors")
    add_authors(contributors, row)

    # Add titles
    titles = ET.SubElement(conference_paper, "titles")
    title = ET.SubElement(titles, "title")
    title.text = row["title"]

    # Add publication date
    publication_date = ET.SubElement(
        conference_paper, "publication_date", media_type="online"
    )
    ET.SubElement(publication_date, "month").text = PUBLICATION_MONTH
    ET.SubElement(publication_date, "day").text = PUBLICATION_DAY
    ET.SubElement(publication_date, "year").text = PUBLICATION_YEAR

    # add doi_data
    doi_data = ET.SubElement(conference_paper, "doi_data")
    ET.SubElement(doi_data, "doi").text = row["doi"]
    ET.SubElement(doi_data, "resource").text = row["calc_url"]
# Out:
# Working on row 0: Unfixing the studio
# Working on row 1: The Work of Untutored Designers & the Future of Design Education
# Working on row 2: Inviting Curiosity: A Framework for Creating Meaningful Experiences
# Working on row 3: User Data: A North Star in Teaching Methods
# Working on row 4: Competencies and Skills for Designers of Information Services
# Working on row 5: Neurodesign: A Game-Changer in Educational Contexts
# Working on row 6: Practice what you preach: co-designing a lecture on co-design
# Working on row 7: Integrating Design for Reuse in Industrial Design Education: Exploring Children’s Products and Gaining Insights
# Working on row 8: Experience is learning: the Piazza Grace case study.
# Working on row 9: The Flipped Design Classroom: Effectiveness of Online Lectures
# Working on row 10: Intergenerational reflection in a changing world
# Working on row 11: Intergenerational participatory design with the local school community
# Working on row 12: Design Thinking Methodology Over Industrial Design Education
# Working on row 13: The workshop model: Teaching ways of knowing and doing
# Working on row 14: Connecting the PhD in Design: How PhDs Label Their Thesis Research
# Working on row 15: Sustainability-in-Action? Toolkit for Transdisciplinary Design Education
# Working on row 16: Tilting T&L – awakening responsible design practices via the senses
# Working on row 17: Writing in Design Pedagogy: Challenges and Best Practices
# Working on row 18: Teaching Inclusive Design Using Parametric Design Methods
# Working on row 19: Using ChatGPT to extract design concepts from stories
# Working on row 20: Design Education as a Catalyst for Innovation: A Case Study from Singapore
# Working on row 21: Activating the Community Living Archive: Collaborative Place-Based Visual Storytelling for Social Justice
# Working on row 22: Design competency acquisition vs delivery: Do students perceive to have learnt what instructors believe to have taught?
# Working on row 23: The Quest for a Programmatic Framework in Design Studios: Hybrid-Based Learning Alternatives
# Working on row 24: Teaching the Co-Design Canvas in Living Labs
# Working on row 25: Teaching simulation design for interaction design students: prototyping of performative critiques and retrospection
# Working on row 26: Embracing Change While Dancing Around Syllabi: A Case Study of a Design Studies Strand in Swedish Higher Education
# Working on row 27: The Futti Krutti Festival - Teaching Experiences for Social Innovation
# Working on row 28: Evaluating Architectural Design: A Case of the ‘Open Jury’
# Working on row 29: Recursive Prompting: A Case Study of a Method for Collectively Exploring a Design Space
# Working on row 30: Empathy Board: co-designing and decolonising curriculum in distance design education
# Working on row 31: Digital Teaching for Classes in Studios, Practice Rooms, and Labs
# Working on row 32: Unfolding the Self: Storytelling Through Interactive Packaging with Augmented Reality
# Working on row 33: Developing Public Service Hybrid Learning Models Through Community-Engaged Design Education
# Working on row 34: Reflection on Engagement and Participation in Public projects
# Working on row 35: Participation and real-life projects to improve Design education in Brazil
# Working on row 36: Do not believe hype: Critically discussing the role and pedagogical implication of generative AI in Human-Centred and Transdisciplinary Design Education
# Working on row 37: Interalities: a conversation on positionalities, localities, pluralities within design education futures
# Working on row 38: Decoloniality in Design: Weaving Curriculum & Community towards Decolonial Futures
# Working on row 39: The (Re)Search for Inclusive Healthcare:
# Designing Pedagogy and a Reflexive Practice
# Working on row 40: Student-centric reflections: A discussion of reflexive practice factors
# Working on row 41: Developing Flexible Systems of Cohesive Curriculum
# Working on row 42: Who the Freedom? – When Design meets Theatre
# Working on row 43: Design Methodology on Fire! Open exchange of e-mails on Design Methodology vs Design Thinking in Design Education
# Working on row 44: When Is the Pluriverse?
# Working on row 45: Online Teaching: Design and Health Insights for Future Pedagogies
# Working on row 46: How to Explain Design Research To Your Friends
# Working on row 47: The Operational Practices of Internationalized Design Curriculum
# Working on row 48: Reflective Teaching Practices and Inclusive Learning Environments
# Working on row 49: Towards strengthening Methods in Design Education and Practice
# Working on row 50: Unpacking positionality & intersectionality within design education
# Working on row 51: The Myth of One-on-One Design Education: Collaborative Futures
# Working on row 52: A Personal Teaching Philosophy & Guiding Principles
# Working on row 53: ‘Padman’, a cinematic design process pedagogical experience
# Working on row 54: The Dialectics of Creativity: The Abstract and the Concrete
# Working on row 55: Urdu Expressive Lettering: an Exploratory Case
# Working on row 56: Advanced Design Thinking (ADT): A Pathway to Deschooling Design
# Working on row 57: Program or be Programmed? Teaching algorithmic principles to future designers
# Working on row 58: Becoming designers with Earth: propositions for design education
# Working on row 59: Institutional Framework for Design Entrepreneurship in Education
# Working on row 60: From Consumer Capitalism to Wellbeing: Re-imagining Futures of Design Education in the View of Pluriverse
# Working on row 61: Teaching Writing In Industrial Design Schools: Defending an Undervalued Tool for Design Practice
# Working on row 62: Communicating interculturally through design: Reflections on a workshop
# Working on row 63: Learning About Design’s Colonial Pasts and Narrative Games
# Working on row 64: Evaluation of the Effectiveness and User Feedback of the AR Vocabulary Card Application for English Vocabulary Learning
# Working on row 65: Learning design as a human right: the beginnings of a design lab founded on critical pedagogy
# Working on row 66: Educating Designers for the New Era: Current Challenges
# Working on row 67: Design Expertise: Differences and Similarities across Industrial Design, Architecture and Engineering Design
# Working on row 68: Mātauranga Moana: uplifting Māori and Pacific values of conceptualisation over western co-design constructs
# Working on row 69: The Decision
# Working on row 70: Blended Design Education: Experiences, Challenges and Opportunities
# Working on row 71: ‘…This is how things are done’: Dismantling the Master-and-Apprentice design pedagogy fallacy with Social Support and Growth Mindset
# Working on row 72: Making Histories: changing students’ perception on the value of their work using the Research Catalogue
# Working on row 73: “Jumping Into the Water Without Knowing How to Swim”: Towards Pedagogical Empowerment and Wellbeing of (Future) Design Teachers
# Working on row 74: A Critical Inquiry on Design Cognition and Generative Systems
# Working on row 75: Building impact: Embedding design PhD researchers in industry contexts
# Working on row 76: An Education Model for Creating Engagement in SDG Action
# Working on row 77: Design from Waste Materials: Situation, Problem, and Solution
# Working on row 78: Revealing student-led pedagogies of care
# Working on row 79: Shortcomings in Design Education: Exploring Metacognitive Activities
# Working on row 80: Transforming Tradition to Amplify Inclusive Learning in Design Studios
# Working on row 81: Considering the role of Higher Education in the success of women in Design
# Working on row 82: Mutate Design Education through Active and Contemplative Leaders.
# Working on row 83: Exploring the Influence of Students’ Personality Types in Computing Design-Project Based Learning
# Working on row 84: Liberal Education as a Catalyst in Shaping the Future of Design
# Working on row 85: Realising a hybrid design studio in basic design
# Working on row 86: Socially Shared Regulation of Design Learning: “Study Dating” amongst Design Students
# Working on row 87: Applying A Make-First Approach to The Diagnostic Design Process
# Working on row 88: Teaching Practices on More-than-human Perspectives in HCI Education – Current State and Future Paths
# Working on row 89: Investing in soft skills in (interior) architectural design education?!
# Working on row 90: Empowerment & Participatory Design for Career Exploration in College
# Working on row 91: Interactions between analogue and digital explorations in Computational Design: lessons learned from Architectural Workshops
# Working on row 92: Design education practices from feminist perspectives in Brazil
# Working on row 93: Blood, Sweat and Tears: A Design Education Research Publication Story
# Working on row 94: Virtual Reality in the study of daylight for sustainable architecture
# Working on row 95: A case for Somatic Approaches in Design Education
# Working on row 96: Shaping the future: The Relevance of STS when teaching Design History
# Working on row 97: Teaching Design Ethics Through Tabletop Game Prototyping
# Working on row 98: Bridging the Intergenerational Digital Divide through Pedagogical Interventions – A Letter to My Future Self
# Working on row 99: Letters - Design Education 4.0
# Working on row 100: Slow down! Breathe! Artificial Intelligence (AI) anxiety in design education
# Working on row 101: Minutes of the Inaugural Disassembly – Patadesign School 1: Ethernity, Day 4 on Absolute 13, 149 P.E. (Sept. 20, 2021 vulg.)
# Working on row 102: Unlearning Unsustainability in Design Education
# Working on row 103: Design for Cleanability: A Human/ Eco-Centred Partnership
# Working on row 104: Towards actualizing the potential of design: change theories to inform critical design education
# Working on row 105: The Pluriversal Future of Design Education
# Working on row 106: Learn X Design 2023 Editorial

# %% [markdown]
# ## Put Together XML and make it pretty

# %%
try:
    tree = ET.ElementTree(doi_batch)

    # Create a string from the XML tree
    xml_string = ET.tostring(doi_batch, encoding="utf-8", xml_declaration=True).decode(
        "utf-8"
    )

    # Use minidom to format the string
    pretty_xml = minidom.parseString(xml_string).toprettyxml(indent="  ")

    # Write the pretty XML to a file
    with open(f"{OUT_FILE_NAME}.xml", "w", encoding="utf-8") as xml_file:
        xml_file.write(pretty_xml)

    print(f"XML file created successfully")
except Exception as e:
    print(f"Error writing XML file: {e}")
# Out:
# XML file created successfully
